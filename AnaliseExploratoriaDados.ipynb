# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrosena138/if1014-data-mining/blob/main/AnaliseExploratoriaDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplina: Solucoes em Mineracao de dados
#--------------------------------------------------------
#Script para a analise exploratoria dos dados (AED)
#--------------------------------------------------------


# Importando as bibliotecas necessarias
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]

# Fazendo o carregamento dos dados diretamente do UCI Machine Learning
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Definindo o nome de cada coluna dos dados
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pandas.read_csv(url, names=names)

print("Apresentando o shape dos dados (dimenssoes)")
print(dataset.shape)

print("Visualizando o conjunto inicial (head) dos dados, ou mais claramente, os 5 primeiros registros (head(5))")
print(dataset.head(5))

print("Conhecendo os dados estatisticos dos dados carregados (describe)")
print(dataset.describe())

print("Conhecendo a distribuicao dos dados por classes (class distribution)")
print(dataset.groupby('class').size())

print("Criando grafios de caixa da distribuicao das classes")
dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

print("Criando histogramas dos dados por classes")
dataset.hist()
plt.show()

print("Criando graficos de dispersao dos dados com paleta de cores")
colors_palette = {'Iris-setosa': 'red', 'Iris-versicolor': 'yellow', 'Iris-virginica': 'green'}
colors = [colors_palette[c] for c in dataset['class']]
scatter_matrix(dataset, c=colors)
plt.show()
# Out:
# Apresentando o shape dos dados (dimenssoes)
# (150, 5)
# Visualizando o conjunto inicial (head) dos dados, ou mais claramente, os 5 primeiros registros (head(5))
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# Conhecendo os dados estatisticos dos dados carregados (describe)
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
# Conhecendo a distribuicao dos dados por classes (class distribution)
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64
# Criando grafios de caixa da distribuicao das classes
# Criando histogramas dos dados por classes
# Criando graficos de dispersao dos dados com paleta de cores

# %%
#Disciplina: Solucoes de Mineracao de dados
#--------------------------------------------------------
#Script para a analise exploratoria dos dados (AED)
#--------------------------------------------------------


# Importando as bibliotecas necessarias
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# Fazendo o carregamento dos dados diretamente do UCI Machine Learning
url="http://archive.ics.uci.edu/ml/machine-learning-databases/arrhythmia/arrhythmia.data"

# Definindo o nome de cada coluna dos dados
names = ['age','sex','height	weight','QRSduration','PRinterval','Q-Tinterval','Tinterval','Pinterval','QRS','T','P','QRST','J','heartrate','chDI_Qwave','chDI_Rwave','chDI_Swave','chDI_RPwave','chDI_SPwave','chDI_intrinsicReflecttions','chDI_RRwaveExists','chDI_DD_RRwaveExists','chDI_RPwaveExists','chDI_DD_RPwaveExists','chDI_RTwaveExists','chDI_DD_RTwaveExists','chDII_Qwave','chDII_Rwave','chDII_Swave','chDII_RPwave','chDII_SPwave','chDII_intrinsicReflecttions','chDII_RRwaveExists','chDII_DD_RRwaveExists','chDII_RPwaveExists','chDII_DD_RPwaveExists','chDII_RTwaveExists','chDII_DD_RTwaveExists','chDIII_Qwave','chDIII_Rwave','chDIII_Swave','chDIII_RPwave','chDIII_SPwave','ch
print(dataset.head(5))

print("Conhecendo os dados estatisticos dos dados carregados (describe)")
print(dataset.describe())

print("Conhecendo a distribuicao dos dados por classes (class distribution)")
print(dataset.groupby('class').size())

print("Criando grafios de caixa da distribuicao das classes")
dataset.plot(kind='box', subplots=True, layout=(17,17), sharex=False, sharey=False)
plt.show()

print("Criando histogramas dos dados por classes")
dataset.hist()
plt.show()

print("Criando graficos de dispersao dos dados")
scatter_matrix(dataset)
plt.show()
# Out:
# Apresentando o shape dos dados (dimenssoes)
# (452, 279)
# Visualizando o conjunto inicial (head) dos dados, ou mais claramente os 5 primeiros registros (head(5))
#     age  sex  height\tweight  QRSduration  PRinterval  Q-Tinterval  Tinterval  \
# 75    0  190              80           91         193          371        174
# 56    1  165              64           81         174          401        149
# 54    0  172              95          138         163          386        185
# 55    0  175              94          100         202          380        179
# 75    0  190              80           88         181          360        177
#
#     Pinterval  QRS   T  ... chV6_QwaveAmp chV6_RwaveAmp chV6_SwaveAmp  \
# 75        121  -16  13  ...           0.0           9.0          -0.9
# 56         39   25  37  ...           0.0           8.5           0.0
# 54        102   96  34  ...           0.0           9.5          -2.4
# 55        143   28  11  ...           0.0          12.2          -2.2
# 75        103  -16  13  ...           0.0          13.1          -3.6
#
#    chV6_RPwaveAmp  chV6_SPwaveAmp  chV6_PwaveAmp  chV6_TwaveAmp  chV6_QRSA  \
# 75            0.0             0.0            0.9            2.9       23.3
# 56            0.0             0.0            0.2            2.1       20.4
# 54            0.0             0.0            0.3            3.4       12.3
# 55            0.0             0.0            0.4            2.6       34.6
# 75            0.0             0.0           -0.1            3.9       25.4
#
#     chV6_QRSTA  class
# 75        49.4      8
# 56        38.8      6
# 54        49.0     10
# 55        61.6      1
# 75        62.8      7
#
# [5 rows x 279 columns]
# Conhecendo os dados estatisticos dos dados carregados (describe)
#               age         sex  height\tweight  QRSduration  PRinterval  \
# count  452.000000  452.000000      452.000000   452.000000  452.000000
# mean     0.550885  166.188053       68.170354    88.920354  155.152655
# std      0.497955   37.170340       16.590803    15.364394   44.842283
# min      0.000000  105.000000        6.000000    55.000000    0.000000
# 25%      0.000000  160.000000       59.000000    80.000000  142.000000
# 50%      1.000000  164.000000       68.000000    86.000000  157.000000
# 75%      1.000000  170.000000       79.000000    94.000000  175.000000
# max      1.000000  780.000000      176.000000   188.000000  524.000000
#
#        Q-Tinterval   Tinterval   Pinterval         QRS  chDI_Qwave  ...  \
# count   452.000000  452.000000  452.000000  452.000000  452.000000  ...
# mean    367.207965  169.949115   90.004425   33.676991    5.628319  ...
# std      33.385421   35.633072   25.826643   45.431434   10.650001  ...
# min     232.000000  108.000000    0.000000 -172.000000    0.000000  ...
# 25%     350.000000  148.000000   79.000000    3.750000    0.000000  ...
# 50%     367.000000  162.000000   91.000000   40.000000    0.000000  ...
# 75%     384.000000  179.000000  102.000000   66.000000   12.000000  ...
# max     509.000000  381.000000  205.000000  169.000000   88.000000  ...
#
#        chV6_QwaveAmp  chV6_RwaveAmp  chV6_SwaveAmp  chV6_RPwaveAmp  \
# count     452.000000     452.000000     452.000000      452.000000
# mean       -0.278982       9.048009      -1.457301        0.003982
# std         0.548876       3.472862       2.002430        0.050118
# min        -4.100000       0.000000     -28.600000        0.000000
# 25%        -0.425000       6.600000      -2.100000        0.000000
# 50%         0.000000       8.800000      -1.100000        0.000000
# 75%         0.000000      11.200000       0.000000        0.000000
# max         0.000000      23.600000       0.000000        0.800000
#
#        chV6_SPwaveAmp  chV6_PwaveAmp  chV6_TwaveAmp   chV6_QRSA  chV6_QRSTA  \
# count           452.0     452.000000     452.000000  452.000000  452.000000
# mean              0.0       0.514823       1.222345   19.326106   29.473230
# std               0.0       0.347531       1.426052   13.503922   18.493927
# min               0.0      -0.800000      -6.000000  -44.200000  -38.600000
# 25%               0.0       0.400000       0.500000   11.450000   17.550000
# 50%               0.0       0.500000       1.350000   18.100000   27.900000
# 75%               0.0       0.700000       2.100000   25.825000   41.125000
# max               0.0       2.400000       6.000000   88.800000  115.900000
#
#             class
# count  452.000000
# mean     3.880531
# std      4.407097
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      6.000000
# max     16.000000
#
# [8 rows x 274 columns]
# Conhecendo a distribuicao dos dados por classes (class distribution)
# class
# 1     245
# 2      44
# 3      15
# 4      15
# 5      13
# 6      25
# 7       3
# 8       2
# 9       9
# 10     50
# 14      4
# 15      5
# 16     22
# dtype: int64
# Criando grafios de caixa da distribuicao das classes
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Criando histogramas dos dados por classes
# Criando graficos de dispersao dos dados

# %%
#Disciplina: Solucoes de Mineracao de dados
#--------------------------------------------------------
#Script para a analise exploratoria dos dados (AED)
#--------------------------------------------------------


# Importando as bibliotecas necessarias
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]

# Especificando a URL da base de dados
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data"

#definindo os nomes de cada coluna
names = [ 'Id number', 'refractive index', 'Magnesium', 'Aluminum', 'Silicon', 
          'Potassium', 'Calcium', 'Barium', 'Iron', 'class']

#Fazendo o carregamento dos dados diretamente do UCI Machine Learning          
dataset = pandas.read_csv(url, names=names)

#remove a primeira coluna que contem o indice
dataset.drop([dataset.columns[0]], axis=1, inplace=True)

print("Apresentando o shape dos dados (dimenssoes)")
print(dataset.shape)

print("Visualizando o conjunto inicial (head) dos dados, ou mais claramente"
		"os 20 primeiros registros (head(20))")
print(dataset.head(20))

print("Conhecendo os dados estatisticos dos dados carregados (describe)")
print(dataset.describe())

print("Conhecendo a distribuicao dos dados por classes (class distribution)")
print(dataset.groupby('class').size())

print("Criando grafios de caixa da distribuicao das classes")
dataset.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False)
plt.show()

print("Criando histogramas dos dados por classes")
dataset.hist()
plt.show()

print("Criando graficos de dispersao dos dados com paleta de cores")
colors_palette = {1: 'red', 2: 'yellow', 3: 'green', 5: 'black', 6: 'blue', 7: 'gray'}
colors = [colors_palette[c] for c in dataset['class']]
scatter_matrix(dataset, c=colors)
plt.show()
# Out:
# Apresentando o shape dos dados (dimenssoes)
# (214, 9)
# Visualizando o conjunto inicial (head) dos dados, ou mais claramenteos 20 primeiros registros (head(20))
#     refractive index  Magnesium  Aluminum  Silicon  Potassium  Calcium  \
# 1              13.64       4.49      1.10    71.78       0.06     8.75
# 2              13.89       3.60      1.36    72.73       0.48     7.83
# 3              13.53       3.55      1.54    72.99       0.39     7.78
# 4              13.21       3.69      1.29    72.61       0.57     8.22
# 5              13.27       3.62      1.24    73.08       0.55     8.07
# 6              12.79       3.61      1.62    72.97       0.64     8.07
# 7              13.30       3.60      1.14    73.09       0.58     8.17
# 8              13.15       3.61      1.05    73.24       0.57     8.24
# 9              14.04       3.58      1.37    72.08       0.56     8.30
# 10             13.00       3.60      1.36    72.99       0.57     8.40
# 11             12.72       3.46      1.56    73.20       0.67     8.09
# 12             12.80       3.66      1.27    73.01       0.60     8.56
# 13             12.88       3.43      1.40    73.28       0.69     8.05
# 14             12.86       3.56      1.27    73.21       0.54     8.38
# 15             12.61       3.59      1.31    73.29       0.58     8.50
# 16             12.81       3.54      1.23    73.24       0.58     8.39
# 17             12.68       3.67      1.16    73.11       0.61     8.70
# 18             14.36       3.85      0.89    71.36       0.15     9.15
# 19             13.90       3.73      1.18    72.12       0.06     8.89
# 20             13.02       3.54      1.69    72.73       0.54     8.44
#
#     Barium  Iron  class
# 1      0.0  0.00      1
# 2      0.0  0.00      1
# 3      0.0  0.00      1
# 4      0.0  0.00      1
# 5      0.0  0.00      1
# 6      0.0  0.26      1
# 7      0.0  0.00      1
# 8      0.0  0.00      1
# 9      0.0  0.00      1
# 10     0.0  0.11      1
# 11     0.0  0.24      1
# 12     0.0  0.00      1
# 13     0.0  0.24      1
# 14     0.0  0.17      1
# 15     0.0  0.00      1
# 16     0.0  0.00      1
# 17     0.0  0.00      1
# 18     0.0  0.00      1
# 19     0.0  0.00      1
# 20     0.0  0.07      1
# Conhecendo os dados estatisticos dos dados carregados (describe)
#        refractive index   Magnesium    Aluminum     Silicon   Potassium  \
# count        214.000000  214.000000  214.000000  214.000000  214.000000
# mean          13.407850    2.684533    1.444907   72.650935    0.497056
# std            0.816604    1.442408    0.499270    0.774546    0.652192
# min           10.730000    0.000000    0.290000   69.810000    0.000000
# 25%           12.907500    2.115000    1.190000   72.280000    0.122500
# 50%           13.300000    3.480000    1.360000   72.790000    0.555000
# 75%           13.825000    3.600000    1.630000   73.087500    0.610000
# max           17.380000    4.490000    3.500000   75.410000    6.210000
#
#           Calcium      Barium        Iron       class
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# min      5.430000    0.000000    0.000000    1.000000
# 25%      8.240000    0.000000    0.000000    1.000000
# 50%      8.600000    0.000000    0.000000    2.000000
# 75%      9.172500    0.000000    0.100000    3.000000
# max     16.190000    3.150000    0.510000    7.000000
# Conhecendo a distribuicao dos dados por classes (class distribution)
# class
# 1    70
# 2    76
# 3    17
# 5    13
# 6     9
# 7    29
# dtype: int64
# Criando grafios de caixa da distribuicao das classes
# Criando histogramas dos dados por classes
# Criando graficos de dispersao dos dados com paleta de cores
